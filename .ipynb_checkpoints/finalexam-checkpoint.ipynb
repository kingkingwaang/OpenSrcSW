# %%
import csv

f = open("country_vaccinations.csv")
data = csv.reader(f)

header = next(data)
max_vac = 0
min_vac = 10000000
max_vac_date = ""
min_vac_date = ""
wvac_list = []
nation_tmp = []
for row in data:
    if row[7] == "":
        temp = 1
    else:
        temp = float(row[7])
    if temp >= max_vac:
        max_vac = temp
        max_vac_date = row[2]
    if temp <= min_vac:
        min_vac = temp
        min_vac_date = row[2]
    vac_list = row[12].split(",")
    if row[0] not in nation_tmp:
        nation_tmp.append(row[0])
        wvac_list[row0] += 1
    
            
print("max_date:",max_vac_date)
print("min_date:",min_vac_date)
# Out:
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ['Johnson&Johnson', ' Oxford/AstraZeneca', ' Pfizer/BioNTech', ' Sinopharm/Beijing']
# ...
